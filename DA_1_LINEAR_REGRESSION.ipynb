# %% [markdown]
# 19BCB0007 - PATIL DARSHAN RAJKUMAR

# %% [markdown]
# # **LINEAR REGRESSION**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.model_selection import train_test_split
import seaborn as sns
import sklearn

# %%
df = pd.read_csv('placement.csv')
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.describe()
# Out:
#               cgpa  placement_exam_marks       placed
# count  1000.000000           1000.000000  1000.000000
# mean      6.961240             32.225000     0.489000
# std       0.615898             19.130822     0.500129
# min       4.890000              0.000000     0.000000
# 25%       6.550000             17.000000     0.000000
# 50%       6.960000             28.000000     0.000000
# 75%       7.370000             44.000000     1.000000
# max       9.120000            100.000000     1.000000

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cgpa                  1000 non-null   float64
#  1   placement_exam_marks  1000 non-null   float64
#  2   placed                1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
df.notnull()
# Out:
#      cgpa  placement_exam_marks  placed
# 0    True                  True    True
# 1    True                  True    True
# 2    True                  True    True
# 3    True                  True    True
# 4    True                  True    True
# ..    ...                   ...     ...
# 995  True                  True    True
# 996  True                  True    True
# 997  True                  True    True
# 998  True                  True    True
# 999  True                  True    True
#
# [1000 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# cgpa                    0
# placement_exam_marks    0
# placed                  0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df['cgpa'], df['placement_exam_marks'], hue=df['placed'])
plt.xlabel('cgpa')
plt.ylabel('placement_exam_marks')
plt.title('cgpa vs placement_exam_marks')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
X = df[['cgpa']]
X
# Out:
#      cgpa
# 0    7.19
# 1    7.46
# 2    7.54
# 3    6.42
# 4    7.23
# ..    ...
# 995  8.87
# 996  9.12
# 997  4.89
# 998  8.62
# 999  4.90
#
# [1000 rows x 1 columns]

# %%
y = df[['placement_exam_marks']]
y
# Out:
#      placement_exam_marks
# 0                    26.0
# 1                    38.0
# 2                    40.0
# 3                     8.0
# 4                    17.0
# ..                    ...
# 995                  44.0
# 996                  65.0
# 997                  34.0
# 998                  46.0
# 999                  10.0
#
# [1000 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7,random_state=100)

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Intercept of the Model:',lm.intercept_)
print('Co-efficient of the line:',lm.coef_)
c=lm.intercept_[0]
m=lm.coef_[0][0]
print("The linear Equation is: Y = {:.5}X + {:.5} ".format(c, m))
# Out:
# Intercept of the Model: [44.11545518]
# Co-efficient of the line: [[-1.68836345]]
# The linear Equation is: Y = 44.115X + -1.6884

# %%
y_predict=lm.predict(X_test)
y_predict
# Out:
# array([[31.52026381],
#        [32.60081642],
#        [32.07742375],
#        [32.44886371],
#        [32.00988921],
#        [33.64760176],
#        [29.76436582],
#        [31.52026381],
#        [32.51639825],
#        [30.40594393],
#        [32.92160548],
#        [31.77351833],
#        [32.71900186],
#        [31.03063841],
#        [32.296911  ],
#        [31.8072856 ],
#        [32.8371873 ],
#        [33.10732546],
#        [30.67608208],
#        [30.35529303],
#        [32.53328188],
#        [34.96452526],
#        [32.39821281],
#        [30.81115116],
#        [32.02677285],
#        [33.2761618 ],
#        [32.58393279],
#        [33.49564905],
#        [33.88397265],
#        [32.00988921],
#        [30.70984935],
#        [31.43584564],
#        [32.71900186],
#        [31.06440568],
#        [32.26314373],
#        [33.10732546],
#        [32.82030367],
#        [33.15797636],
#        [33.49564905],
#        [32.88783821],
#        [33.64760176],
# ...

# %%
plt.scatter (X_test, y_test, color = 'black')
plt.plot (X_test, lm.predict (X_test), color = 'blue')
plt.title('cgpa vs placement_exam_marks')
plt.xlabel('cgpa')
plt.ylabel('placement_exam_marks')
plt.show()

# %%
from sklearn import metrics
print("Mean Absolute Error : ", metrics.mean_absolute_error(y_test, y_predict))
print('Mean Squared Error : ', metrics.mean_squared_error(y_test, y_predict))
print('Root Mean Squared Error : ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
print('R Square value : ', metrics.r2_score(y_test, y_predict))
# Out:
# Mean Absolute Error :  16.210657024792813
# Mean Squared Error :  394.84455058069125
# Root Mean Squared Error :  19.870695774951898
# R Square value :  -0.006776404366076072
